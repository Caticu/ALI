# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Import necessary libraries
import numpy as np

# Define the vectors v1, v2, and u
v1 = (1/2) * np.array([1, -1, 1, -1])
v2 = (1/2) * np.array([1, 1, 1, 1])
u = np.array([3, 1, -1, 5])

# Part a: Check if {v1, v2} is an orthonormal set
# Check orthogonality (dot product should be zero)
orthogonality = np.dot(v1, v2)

# Check if each vector is of unit length (norm should be 1)
norm_v1 = np.linalg.norm(v1)
norm_v2 = np.linalg.norm(v2)

# Part b: Dimension of W (number of linearly independent vectors)
# Since v1 and v2 are given as spanning vectors, the dimension of W is 2
dim_W = 2

# Part c: Dimension of W⊥ (orthogonal complement of W)
# Since W is a 2-dimensional subspace in a 4-dimensional space, dim(W⊥) = 4 - 2 = 2
dim_W_perp = 4 - dim_W

# Part d: Orthogonal projection of u onto W
# The projection of u onto W is given by: proj_W(u) = (u.v1)v1 + (u.v2)v2
proj_u_v1 = (np.dot(u, v1)) * v1
proj_u_v2 = (np.dot(u, v2)) * v2
proj_u_W = proj_u_v1 + proj_u_v2

# Part e: Distance between u and W
# The distance is given by the norm of the difference between u and its projection onto W
distance_u_W = np.linalg.norm(u - proj_u_W)

orthogonality, norm_v1, norm_v2, dim_W, dim_W_perp, proj_u_W, distance_u_W

# %% [markdown]
# Solution:
#
# Let’s address each part of the problem using Python.
#
# 	1.	Check if  \{v_1, v_2\}  is an orthonormal set.
# 	•	A set of vectors is orthonormal if each vector is of unit length and all vectors are orthogonal to each other (i.e., their dot product is 0).
# 	2.	Find the dimension of  W .
# 	•	The dimension of  W  is the number of linearly independent vectors in the set  \{v_1, v_2\} .
# 	3.	Find the dimension of  W^\perp .
# 	•	The dimension of the orthogonal complement  W^\perp  is given by  \text{dim}(W^\perp) = \text{dim}(V) - \text{dim}(W) , where  V  is the entire vector space (which has dimension 4 here).
# 	4.	Compute the orthogonal projection of  u  onto  W .
# 	•	The projection of a vector  u  onto a subspace  W  spanned by vectors  v_1, v_2  can be found using the projection formula.
# 	5.	Find the distance between  u  and  W .
# 	•	The distance is given by the norm of the difference between the vector  u  and its projection onto  W .
